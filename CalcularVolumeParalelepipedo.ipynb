# %%
base = float(input('Digite o valor da base: '))
largura = float(input('Digite o valor da largura: '))
altura = float(input('Digite o valor da altura: '))
volume = base*largura*altura

print('O volume calculado é: ')
print(volume)
# Out:
# Digite o valor da base: 21.5
# Digite o valor da largura: 2.4
# Digite o valor da altura: 1.56
# O volume calculado é:
# 80.49600000000001

# %% [markdown]
# Problema a ser resolvido
#
# Em cada avaliação o usuário pode dar uma nota em quantidade de estrelas para uma música, de 1 a 5. Mapeie as avaliações numéricas em categorias:
#
# entre 0 e 1 estrelas é uma música ruim
#
# entre 2 e 3 é uma música mediana
#
# entre 4 e 5 são para as músicas boas.
#
# Quantas músicas ruins, medianas e boas existem para cada gênero: Rock e Pop.
#
# Existe alguma música mediana de Rock
#
# Todas as músicas de Pop são boas.
#
# Qual gênero musical teve uma maior quantidade de músicas boas.
#
# notas_rock = [5, 1, 4, 0, 2, 5, 2, 1, 0, 5, 5, 3, 5, 2, 5, 5, 3, 5, 4, 4]
#
# notas_pop = [3, 2, 5, 1, 2, 1, 4, 1, 5, 0, 4, 2, 1, 2, 5, 2, 4, 4, 0, 1]

# %%
def categoria(notas_rock):
  if notas_rock <= 1:
    return 'ruim'
  elif 2 <= notas_rock <= 3:
    return 'mediana'
  else:
    return 'boa'

notas_rock = [5, 1, 4, 0, 2, 5, 2, 1, 0, 5, 5, 3, 5, 2, 5, 5, 3, 5, 4, 4]
classificacao = list(map(categoria, notas_rock))

musica_ruim = list(filter(lambda x: x == 'ruim', classificacao))
musica_mediana = list(filter(lambda x: x == 'mediana', classificacao))
musica_boa = list(filter(lambda x: x == 'boa', classificacao))

# Todas as músicas de rock_pop são boas?
# todas_boas = len(notas_rock) == len(musica_boa)

print('Quantos usuários deram notas:', len(notas_rock)) 
#print(classificacao)
print('Vamos saber como ficou a avaliação do gênero de música POP_Rock.')
print('QTD. de músicas RUINS: ', len(musica_ruim))
print('QTD. de músicas MEDIANAS: ', len(musica_mediana))
print('QTD. de músicas BOAS: ', len(musica_boa))
print('Todas as músicas de POP_Rock são boas? ', todas_boas == len(musica_boa))
# Out:
# Quantos usuários deram notas: 20
# Vamos saber como ficou a avaliação do gênero de música POP_Rock.
# QTD. de músicas RUINS:  4
# QTD. de músicas MEDIANAS:  5
# QTD. de músicas BOAS:  11
# Todas as músicas de POP_Rock são boas:  False

# %%
def categoria_pop(notas_pop):
  if notas_pop <= 1:
    return 'ruim'
  elif 2 <= notas_pop <= 3:
    return 'mediana'
  else:
    return 'boa'
  
notas_pop = [3, 2, 5, 1, 2, 1, 4, 1, 5, 0, 4, 2, 1, 2, 5, 2, 4, 4, 0, 1]
classificacao_pop = list(map(categoria_pop, notas_pop))
musica_ruim_pop = list(filter(lambda x: x == 'ruim', classificacao_pop))
musica_mediana_pop = list(filter(lambda x: x == 'mediana', classificacao_pop))
musica_boa_pop = list(filter(lambda x: x == 'boa', classificacao_pop))

print('Quantos usuários deram notas para ao genero POP:', len(notas_pop))
print('Avaliação do gênero POP.')
print('QTD. de músicas RUINS: ', len(musica_ruim_pop))
print('QTD. de músicas MEDIANAS: ', len(musica_mediana_pop))
print('QTD. de músicas BOAS: ', len(musica_boa_pop))
print('Todas as músicas POP são boas? ', len(musica_boa_pop) == len(notas_pop))
# Out:
# Quantos usuários deram notas para ao genero POP: 20
# Avaliação do gênero POP.
# QTD. de músicas RUINS:  7
# QTD. de músicas MEDIANAS:  6
# QTD. de músicas BOAS:  7
# Todas as músicas POP são boas?  False

# %%
pop = int(len(musica_boa_pop))
rock = int(len(musica_boa))
print('QTD. de músicas boas separadas por gênero POP e ROCK.')
print('ROCK, tem: ', rock, ' músicas boas.')
print('POP, tem: ', pop, ' músicas boas.')
if pop > rock:
  print('O gênero musical POP tem mais músicas boas do que o rock.')
else:
  print('O rock tem mais músicas boas do que o POP.')
# Out:
# QTD. de músicas boas separadas por gênero POP e ROCK.
# ROCK, tem:  11  músicas boas.
# POP, tem:  7  músicas boas.
# O rock tem mais músicas boas do que o POP.

# %%
idade = input('Qual a sua idade por favor.')
idadeSua = int(idade)
print('Ano que vem você terá', idadeSua + 1, ' anos')
# Out:
# Qual a sua idade por favor.49
# Ano que vem você terá 50  anos

# %%
notas = (7, 8, 10, 9, 4, 5.5)
print(len(notas))
# Out:
# 6

# %%
notas = (6.5, 7.8, 10.0, 9.1)
i = 0
while i < len(notas):
    if notas[i] >= 7.0:
        print(notas[i], 'é igual ou maior que a média')

# %%
notas = (6.5, 7.8, 10.0, 9.1)
for nota in notas:
    if nota >= 7.0:
        print(nota, 'é igual ou maior que a média')
    else:
        print(nota, 'é menor que a média')
